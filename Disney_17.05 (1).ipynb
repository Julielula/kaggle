# %%
import pandas as pd
df = pd.read_csv("disney-characters.csv")
df
# Out:
#                                  movie_title        release_date  \
# 0          \nSnow White and the Seven Dwarfs   December 21, 1937
# 1                                \nPinocchio    February 7, 1940
# 2                                 \nFantasia   November 13, 1940
# 3                                      Dumbo    October 23, 1941
# 4                                    \nBambi     August 13, 1942
# 5                           \nSaludos Amigos    February 6, 1943
# 6                       The Three Caballeros    February 3, 1945
# 7                          \nMake Mine Music      April 20, 1946
# 8                       \nFun and Fancy Free  September 27, 1947
# 9                              \nMelody Time        May 27, 1948
# 10  \nThe Adventures of Ichabod and Mr. Toad     October 5, 1949
# 11                                Cinderella   February 15, 1950
# 12                     \nAlice in Wonderland       July 28, 1951
# ...

# %%
df["movie_title"]=df["movie_title"].str.replace("\n","")
df
# Out:
#                                movie_title        release_date  \
# 0          Snow White and the Seven Dwarfs   December 21, 1937
# 1                                Pinocchio    February 7, 1940
# 2                                 Fantasia   November 13, 1940
# 3                                    Dumbo    October 23, 1941
# 4                                    Bambi     August 13, 1942
# 5                           Saludos Amigos    February 6, 1943
# 6                     The Three Caballeros    February 3, 1945
# 7                          Make Mine Music      April 20, 1946
# 8                       Fun and Fancy Free  September 27, 1947
# 9                              Melody Time        May 27, 1948
# 10  The Adventures of Ichabod and Mr. Toad     October 5, 1949
# 11                              Cinderella   February 15, 1950
# 12                     Alice in Wonderland       July 28, 1951
# 13                               Peter Pan    February 5, 1953
# ...

# %%
df2 = pd.read_csv("disney_movies_total_gross.csv")
df2
# Out:
#                          movie_title  release_date      genre MPAA_rating  \
# 0    Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                          Pinocchio   Feb 9, 1940  Adventure           G
# 2                           Fantasia  Nov 13, 1940    Musical           G
# 3                  Song of the South  Nov 12, 1946  Adventure           G
# 4                         Cinderella  Feb 15, 1950      Drama           G
# ..                               ...           ...        ...         ...
# 574         The Light Between Oceans   Sep 2, 2016      Drama       PG-13
# 575                   Queen of Katwe  Sep 23, 2016      Drama          PG
# 576                   Doctor Strange   Nov 4, 2016  Adventure       PG-13
# 577                            Moana  Nov 23, 2016  Adventure          PG
# 578     Rogue One: A Star Wars Story  Dec 16, 2016  Adventure       PG-13
#
#       total_gross inflation_adjusted_gross
# ...

# %%
df2["total_gross"]=df2["total_gross"].str.replace("$","")
df2
# Out:
# C:\Users\SHPCTA~1\AppData\Local\Temp/ipykernel_11456/4050910729.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2["total_gross"]=df2["total_gross"].str.replace("$","")
#                          movie_title  release_date      genre MPAA_rating  \
# 0    Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                          Pinocchio   Feb 9, 1940  Adventure           G
# 2                           Fantasia  Nov 13, 1940    Musical           G
# 3                  Song of the South  Nov 12, 1946  Adventure           G
# 4                         Cinderella  Feb 15, 1950      Drama           G
# ..                               ...           ...        ...         ...
# 574         The Light Between Oceans   Sep 2, 2016      Drama       PG-13
# ...

# %%
df2["inflation_adjusted_gross"]=df2["inflation_adjusted_gross"].str.replace("$","")
df2
# Out:
# C:\Users\SHPCTA~1\AppData\Local\Temp/ipykernel_11456/1351253998.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2["inflation_adjusted_gross"]=df2["inflation_adjusted_gross"].str.replace("$","")
#                          movie_title  release_date      genre MPAA_rating  \
# 0    Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                          Pinocchio   Feb 9, 1940  Adventure           G
# 2                           Fantasia  Nov 13, 1940    Musical           G
# 3                  Song of the South  Nov 12, 1946  Adventure           G
# 4                         Cinderella  Feb 15, 1950      Drama           G
# ..                               ...           ...        ...         ...
# 574         The Light Between Oceans   Sep 2, 2016      Drama       PG-13
# ...

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows 
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df2['genre']= label_encoder.fit_transform(df2['genre'])
  
df2['genre'].unique()
# Out:
# array([ 8,  1,  6,  3, 12,  0,  7,  9, 10, 11,  2,  5,  4])

# %%
df2
# Out:
#                          movie_title  release_date  genre MPAA_rating  \
# 0    Snow White and the Seven Dwarfs  Dec 21, 1937      8           G
# 1                          Pinocchio   Feb 9, 1940      1           G
# 2                           Fantasia  Nov 13, 1940      8           G
# 3                  Song of the South  Nov 12, 1946      1           G
# 4                         Cinderella  Feb 15, 1950      6           G
# ..                               ...           ...    ...         ...
# 574         The Light Between Oceans   Sep 2, 2016      6       PG-13
# 575                   Queen of Katwe  Sep 23, 2016      6          PG
# 576                   Doctor Strange   Nov 4, 2016      1       PG-13
# 577                            Moana  Nov 23, 2016      1          PG
# 578     Rogue One: A Star Wars Story  Dec 16, 2016      1       PG-13
#
#      total_gross inflation_adjusted_gross
# 0    184,925,485            5,228,953,251
# ...
